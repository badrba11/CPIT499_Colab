# %% [markdown]
# <a href="https://colab.research.google.com/github/badrba11/CPIT499_Colab/blob/main/Graduation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing packag

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
import pickle 
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ##Data sets loading and preprocessing#

# %%
# loading the data sets
try:
  cold = pd.read_excel('Cold_Water.xlsx')
  hot = pd.read_excel('Hot_Water.xlsx')
# loading test data sets with no output
  ct = pd.read_excel('ColdWater_Test.xlsx')
  ht = pd.read_excel('HotWaterTest.xlsx')
except FileNotFoundError:
  print('File not found')

# %%
# droping the null values
TheNumberOfStates = cold.dropna()
TheNumberOfStates
# Out:
#      Tin cold (°C)  Tout cold (°C)  \
# 0             25.0            24.7
# 220           15.5            15.3
# 268           15.3            20.1
# 414           15.6            32.8
#
#                                                  State
# 0               Decrease the temperature arround 15 °C
# 220         Stabilization of temperature arround 15 °C
# 268  working of the pilot (steady state) temperatur...
# 414                        Fault : Shutdown the cooler

# %%
# display the data set
cold
# Out:
#      Tin cold (°C)  Tout cold (°C)                                   State
# 0             25.0            24.7  Decrease the temperature arround 15 °C
# 1             24.8            24.4                                     NaN
# 2             24.6            24.0                                     NaN
# 3             24.3            23.6                                     NaN
# 4             24.0            23.2                                     NaN
# ..             ...             ...                                     ...
# 672           19.4            26.5                                     NaN
# 673           19.3            26.5                                     NaN
# 674           19.4            26.6                                     NaN
# 675           19.5            25.9                                     NaN
# 676           19.5            25.9                                     NaN
#
# [677 rows x 3 columns]

# %%
a = 'Decrease the temperature arround 15 °C'
b = 'Stabilization of temperature arround 15 °C'
c = 'working of the pilot (steady state) temperature arround 15 °C'
d = 'Fault : Shutdown the cooler'

#fill with approprate ouput
index = 0
while index < 220: 
    cold['State'].iloc[index]  = a
    index +=1
index = 220    
while  index < 268: 
    cold['State'].iloc[index]  = b
    index +=1
index = 269    
while index < 414: 
    cold['State'].iloc[index]  = c
    index +=1
while index < 677: 
    cold['State'].iloc[index]  = d
    index +=1
#print the result
cold
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      Tin cold (°C)  Tout cold (°C)                                   State
# 0             25.0            24.7  Decrease the temperature arround 15 °C
# 1             24.8            24.4  Decrease the temperature arround 15 °C
# 2             24.6            24.0  Decrease the temperature arround 15 °C
# 3             24.3            23.6  Decrease the temperature arround 15 °C
# 4             24.0            23.2  Decrease the temperature arround 15 °C
# ..             ...             ...                                     ...
# 672           19.4            26.5             Fault : Shutdown the cooler
# ...

# %%
# droping the null values
TheNumberOfStates = hot.dropna()
TheNumberOfStates
# Out:
#      Tin Hot (°C)  Tout hot (°C)  \
# 0            33.3           33.2
# 604          63.5           63.1
# 835          65.1           45.2
# 941          64.5           44.5
#
#                                                  State
# 0               Increase the temperature arround 65 °C
# 604         Stabilization of temperature arround 65 °C
# 835  working of the pilot (steady state) temperatur...
# 941                          Fault Shutdown the heater

# %%
# display the data set
hot
# Out:
#       Tin Hot (°C)  Tout hot (°C)                                   State
# 0             33.3           33.2  Increase the temperature arround 65 °C
# 1             33.4           33.2                                     NaN
# 2             33.4           33.2                                     NaN
# 3             33.4           33.3                                     NaN
# 4             33.5           33.3                                     NaN
# ...            ...            ...                                     ...
# 1397          49.2           38.7                                     NaN
# 1398          49.2           38.7                                     NaN
# 1399          49.1           38.6                                     NaN
# 1400          49.2           38.6                                     NaN
# 1401          49.1           37.5                                     NaN
#
# [1402 rows x 3 columns]

# %%
a = 'Increase the temperature arround 65 °C'
b = 'Stabilization of temperature arround 65 °C'
c = 'working of the pilot (steady state) temperature arround 50 °C'
d = 'Fault Shutdown the heater'

#fill with approprate ouput
index = 0
while index < 604: 
    hot['State'].iloc[index]  = a
    index +=1
index = 220    
while  index < 835: 
    hot['State'].iloc[index]  = b
    index +=1
index = 269    
while index < 941: 
    hot['State'].iloc[index]  = c
    index +=1
while index < 1402: 
    hot['State'].iloc[index]  = d
    index +=1
#print the result
hot
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#       Tin Hot (°C)  Tout hot (°C)                                   State
# 0             33.3           33.2  Increase the temperature arround 65 °C
# 1             33.4           33.2  Increase the temperature arround 65 °C
# 2             33.4           33.2  Increase the temperature arround 65 °C
# 3             33.4           33.3  Increase the temperature arround 65 °C
# 4             33.5           33.3  Increase the temperature arround 65 °C
# ...            ...            ...                                     ...
# 1397          49.2           38.7               Fault Shutdown the heater
# ...

# %% [markdown]
# #**ML Models**

# %% [markdown]
# ##**Neural  Network Function**

# %%
def NN(datap,iscross):
 try: 
    
     x=datap.drop(columns=['State'])
     y=datap['State']
     X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)
     nn=MLPClassifier (max_iter=500)
     nn.fit(X_train,y_train)
  
     Prediction=nn.predict(X_test)
 except AttributeError:
          print('wroung attribute') 

 except NameError:
          print('undefined value name')

 except ValueError:
          print ('wrong value')
 else: 
        
     if(iscross):
         score = cross_val_score(nn , x , y , cv = 10) 
         return print('Ten folds Cross validation :{:.2f}'
         .format(sum(score)/len(score)))
     else: 
         score=accuracy_score(Prediction,y_test) 
         return print('Accuracy of NN classifier on test set: {:.2f}'
         .format(score))

# %%
print('\nNormal data hot water with cross validation')

NN(hot,True)

print('\nNormal data cold water with cross validation')

NN(cold,True)

# without cross validation
print('\nNormal data hot water without cross validation')

NN(hot,False)
print('\nNormal data cold water without cross validation')

NN(cold,False)
# Out:
# Normal data hot water with cross validation
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Ten folds Cross validation :0.88
#
# Normal data cold water with cross validation
# Ten folds Cross validation :0.90
#
# Normal data hot water without cross validation
# Accuracy of NN classifier on test set: 0.88
#
# Normal data cold water without cross validation
# Accuracy of NN classifier on test set: 0.92
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ##**Decision Tree Model Function**

# %%
# Function to Tets Accurcy   
def DT(datap,maxdepth,iscross): 
 try:
   model=DecisionTreeClassifier(max_depth=maxdepth)
   x=datap.drop(columns=['State'])
   y=datap['State']
   X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=20)

   model.fit(X_train,y_train)
   Prediction=model.predict(X_test) 
 except AttributeError:
          print('wroung attribute') 

 except NameError:
          print('undefined value name')

 except ValueError:
          print ('wrong value')
 else: 
  if(iscross):
      score = cross_val_score(model , x , y , cv = 10) 
      return print('Ten folds Cross validation :{:.2f}'
      .format(sum(score)/len(score)))
  else: 
      score=accuracy_score(Prediction,y_test) 
      return print('Accuracy of Decision Tree Model classifier on test set: {:.2f}'
      .format(score))

# %%
print('Normal data hot water with cross validation')
DT(hot,5,True)

print('\nNormal data cold water with cross validation')
DT(cold,5,True)

print('\nNormal data hot water without cross validation')
DT(hot,5,False)

print('\nNormal data cold water without cross validation')
DT(cold,5,False)
# Out:
# Normal data hot water with cross validation
# Ten folds Cross validation :0.95
#
# Normal data cold water with cross validation
# Ten folds Cross validation :0.94
#
# Normal data hot water without cross validation
# Accuracy of Decision Tree Model classifier on test set: 1.00
#
# Normal data cold water without cross validation
# Accuracy of Decision Tree Model classifier on test set: 0.99

# %% [markdown]
# ##**K-Nearest Neighbors Function**

# %%
def KNN(datap,iscross): 
  try:
   model=KNeighborsClassifier()
   x=datap.drop(columns=['State'])
   y=datap['State']
   X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=20)

   model.fit(X_train,y_train)
   Prediction=model.predict(X_test) 
 
  except AttributeError:
          print('wroung attribute') 

  except NameError:
          print('undefined value name')

  except ValueError:
          print ('wrong value')
  else: 
   if(iscross):
      score = cross_val_score(model , x , y , cv = 10) 
      return print('Ten folds Cross validation :{:.2f}'
      .format(sum(score)/len(score))) 
   else:
      score=accuracy_score(Prediction,y_test) 
      return print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(score))

# %%
print('Normal data hot water with cross validation')
KNN(hot,True)

print('Normal data cold water with cross validation')
KNN(cold,True)

print('Normal data hot water without cross validation')
KNN(hot,False)

print('Normal data cold water without cross validation')
KNN(cold,False)
# Out:
# Normal data hot water with cross validation
# Ten folds Cross validation :0.95
# Normal data cold water with cross validation
# Ten folds Cross validation :0.95
# Normal data hot water without cross validation
# Accuracy of K-NN classifier on test set: 0.99
# Normal data cold water without cross validation
# Accuracy of K-NN classifier on test set: 0.98

# %% [markdown]
# ##**Naive Bayes Function**

# %%
def naive(datap,iscross):
  try: 
   gnb = GaussianNB() 
   x=datap.drop(columns=['State'])
   y=datap['State']
   X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=25)

   gnb.fit(X_train,y_train)

   Prediction=gnb.predict(X_test)   
  except AttributeError:
          print('wroung attribute') 

  except NameError:
          print('undefined value name')

  except ValueError:
          print ('wrong value')
  else: 
   if(iscross):
      score = cross_val_score(gnb , x , y , cv = 10) 
      return print('Ten folds Cross validation  :{:.2f}'
      .format(sum(score)/len(score))) 
   else:
      score=accuracy_score(Prediction,y_test) 
      return print('Accuracy of Decision Tree classifier on test set is : {:.2f}'
      .format(score))

# %%
print('Normal data hot water with cross validation')
naive(hot,True)

print('Normal data cold water with cross validation')
naive(cold,True)

print('Normal data hot water without cross validation')
naive(hot,False)

print('Normal data cold water without cross validation')
naive(cold,False)
# Out:
# Normal data hot water with cross validation
# Ten folds Cross validation  :0.93
# Normal data cold water with cross validation
# Ten folds Cross validation  :0.97
# Normal data hot water without cross validation
# Accuracy of Decision Tree classifier on test set is : 0.97
# Normal data cold water without cross validation
# Accuracy of Decision Tree classifier on test set is : 0.97

# %% [markdown]
# #Testing the ML Model

# %%
#cold water data KNN
model=KNeighborsClassifier()
x=cold.drop(columns=['State'])
y=cold['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

model.fit(X_train,y_train)
model.predict(ct)
# Out:
# array(['Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
# ...

# %%
#hot water data KNN
model=KNeighborsClassifier()
x=hot.drop(columns=['State'])
y=hot['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

model.fit(X_train,y_train)
model.predict(ht)
# Out:
# array(['Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C', ...,
#        'Fault Shutdown the heater', 'Fault Shutdown the heater',
#        'Fault Shutdown the heater'], dtype=object)

# %%
#cold water data Decision Tree
modelCold=DecisionTreeClassifier(max_depth=4)
x=cold.drop(columns=['State'])
y=cold['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelCold.fit(X_train,y_train)
modelCold.predict(ct)
# Out:
# array(['Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
# ...

# %%
#hot water data Decision Tree
modelHot=DecisionTreeClassifier(max_depth=4)
x=hot.drop(columns=['State'])
y=hot['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelHot.fit(X_train,y_train)
modelHot.predict(ht)
# Out:
# array(['Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C', ...,
#        'Fault Shutdown the heater', 'Fault Shutdown the heater',
#        'Fault Shutdown the heater'], dtype=object)

# %%
#cold water data Naive Bayes 
modelCold=GaussianNB()
x=cold.drop(columns=['State'])
y=cold['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelCold.fit(X_train,y_train)
modelCold.predict(ct)
# Out:
# array(['Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
# ...

# %%
#hot water data Naive Bayes
modelHot=GaussianNB()
x=hot.drop(columns=['State'])
y=hot['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelHot.fit(X_train,y_train)
modelHot.predict(ht)
# Out:
# array(['Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C', ...,
#        'Fault Shutdown the heater', 'Fault Shutdown the heater',
#        'Increase the temperature arround 65 °C'], dtype='<U61')

# %%
##cold water data Neural Networks
modelCold=MLPClassifier()
x=cold.drop(columns=['State'])
y=cold['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelCold.fit(X_train,y_train)
modelCold.predict(ct)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# array(['Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
#        'Decrease the temperature arround 15 °C',
# ...

# %%
##hot water data Neural Networks
modelHot=MLPClassifier()
x=hot.drop(columns=['State'])
y=hot['State']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

modelHot.fit(X_train,y_train)
modelHot.predict(ht)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# array(['Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C',
#        'Increase the temperature arround 65 °C', ...,
#        'Fault Shutdown the heater', 'Fault Shutdown the heater',
#        'Fault Shutdown the heater'], dtype='<U61')

# %% [markdown]
# #**Using Pickel Library to Store the Model**

# %%
#function to retun the model as an object 
def DTM(datap,maxdepth): 
   model=DecisionTreeClassifier(max_depth=maxdepth)
   x=datap.drop(columns=['State'])
   y=datap['State']
   X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=20)

   model.fit(X_train,y_train)
   Prediction=model.predict(X_test) 
   return model 

## Choose Decsion Tree as the model to use    
modelHot=DTM(hot,5)


modelCold=DTM(cold,5)


pickle.dump(modelHot , open('MLModelHot', 'wb'))


pickle.dump(modelCold , open('MLModelCold', 'wb'))

# %% [markdown]
# ##**Testing the Pickl files**

# %%
model=pickle.load(open('MLModelCold','rb'))
arr = np.array([[90,90]])

try:
     model.predict(arr)
except ValueError:
    print ('wrong value')
else:
    print ('correct value')
# Out:
# correct value
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
